# %% [markdown]
# <a href="https://colab.research.google.com/github/hfazlul/DS_BasicPy/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
url='https://raw.githubusercontent.com/FazlyRabbiBD/StatisticsBasic/master/GPA.csv'
df=pd.read_csv(url)
df
# Out:
#      Name  StudyTime  GamingHour   GPA
# 0   Monir        4.0         0.5  3.55
# 1    Jony        2.5         1.0  2.35
# 2   Gopal        3.0         0.5  3.07
# 3   Habib        6.0         0.0  3.93
# 4    Kona        5.0         0.5  3.97
# 5   Bablu        1.0         3.0  2.43
# 6    Sara        3.5         0.0  3.61
# 7   Javed        4.0         0.5  3.67
# 8   Hasib        2.0         1.0  2.97
# 9  Hridoy        1.5         2.0  2.81

# %%
df.count()
# Out:
# Name          10
# StudyTime     10
# GamingHour    10
# GPA           10
# dtype: int64

# %%
df.GamingHour.sum()
# Out:
# 9.0

# %%
df.columns = df.columns.str.strip()  # Remove spaces before and after
df.columns = df.columns.str.replace(" ", "")  # Remove spaces inside names

# Check column names
print(df.columns)
# Out:
# Index(['Name', 'StudyTime', 'GamingHour', 'GPA'], dtype='object')

# %%
df.GamingHour.cumsum()
# Out:
# 0    0.5
# 1    1.5
# 2    2.0
# 3    2.0
# 4    2.5
# 5    5.5
# 6    5.5
# 7    6.0
# 8    7.0
# 9    9.0
# Name: GamingHour, dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# StudyTime     3.250
# GamingHour    0.900
# GPA           3.236
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# StudyTime     3.25
# GamingHour    0.50
# GPA           3.31
# dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'StudyTime', 'GamingHour', 'GPA'], dtype='object')

# %%
df.StudyTime.mode()
# Out:
# 0    4.0
# Name: StudyTime, dtype: float64

# %%
df.GamingHour.mode()
# Out:
# 0    0.5
# Name: GamingHour, dtype: float64

# %%
df.min()
df.max()
# Out:
# Name          Sara
# StudyTime      6.0
# GamingHour     3.0
# GPA           3.97
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'StudyTime', 'GamingHour', 'GPA'], dtype='object')

# %%
range=df[['StudyTime','GamingHour','GPA']].max()-df[['StudyTime','GamingHour','GPA']].min()
range
# Out:
# StudyTime     5.00
# GamingHour    3.00
# GPA           1.62
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# StudyTime     2.458333
# GamingHour    0.877778
# GPA           0.351293
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# StudyTime     1.567907
# GamingHour    0.936898
# GPA           0.592700
# dtype: float64

# %%
df.cov(numeric_only=True)
# Out:
#             StudyTime  GamingHour       GPA
# StudyTime    2.458333   -1.194444  0.827222
# GamingHour  -1.194444    0.877778 -0.418222
# GPA          0.827222   -0.418222  0.351293
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['StudyTime'].plot(kind='hist', bins=20, title='StudyTime')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['GamingHour'].plot(kind='hist', bins=20, title='GamingHour')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['GPA'].plot(kind='hist', bins=20, title='GPA')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.corr(numeric_only=True)
# Out:
#             StudyTime  GamingHour       GPA
# StudyTime    1.000000   -0.813117  0.890157
# GamingHour  -0.813117    1.000000 -0.753147
# GPA          0.890157   -0.753147  1.000000

# %%
df.skew(numeric_only=True)
# Out:
# StudyTime     0.283764
# GamingHour    1.499697
# GPA          -0.283563
# dtype: float64

# %%
df.kurtosis(numeric_only=True)
# Out:
# StudyTime    -0.548118
# GamingHour    1.985173
# GPA          -1.396490
# dtype: float64

# %%
df.quantile(.25,numeric_only=True)
# Out:
# StudyTime     2.125
# GamingHour    0.500
# GPA           2.850
# Name: 0.25, dtype: float64

# %%
iqr=df.quantile(.75,numeric_only=True)-df.quantile(.25,numeric_only=True)
iqr
# Out:
# StudyTime     1.875
# GamingHour    0.500
# GPA           0.805
# dtype: float64

# %%
df.describe()
# Out:
#        StudyTime  GamingHour      GPA
# count  10.000000   10.000000  10.0000
# mean    3.250000    0.900000   3.2360
# std     1.567907    0.936898   0.5927
# min     1.000000    0.000000   2.3500
# 25%     2.125000    0.500000   2.8500
# 50%     3.250000    0.500000   3.3100
# 75%     4.000000    1.000000   3.6550
# max     6.000000    3.000000   3.9700

# %%
df.describe(include='all')
# Out:
#          Name  StudyTime  GamingHour      GPA
# count      10  10.000000   10.000000  10.0000
# unique     10        NaN         NaN      NaN
# top     Monir        NaN         NaN      NaN
# freq        1        NaN         NaN      NaN
# mean      NaN   3.250000    0.900000   3.2360
# std       NaN   1.567907    0.936898   0.5927
# min       NaN   1.000000    0.000000   2.3500
# 25%       NaN   2.125000    0.500000   2.8500
# 50%       NaN   3.250000    0.500000   3.3100
# 75%       NaN   4.000000    1.000000   3.6550
# max       NaN   6.000000    3.000000   3.9700
